# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreLeitao906/ListadeExercicio/blob/main/Trabalhando_Lista_Sequ%C3%AAncial_2024/resposta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabalhando com Lista sequencial
#
# Uma lista sequencial, também conhecida como array ou vetor, é uma estrutura de dados que armazena elementos em posições contíguas de memória. Cada elemento da lista é identificado por um índice, que representa sua posição na lista, começando normalmente do zero. As listas sequenciais são fundamentais em várias aplicações de programação e algoritmos devido à sua eficiência em acessar elementos diretamente pelo índice.
#
# * Características principais:
#
#   **Acesso Direto**: Os elementos podem ser acessados diretamente usando o índice, o que permite operações de leitura e escrita rápidas.
#
#   **Tamanho Fixo ou Dinâmico**: Em algumas linguagens, as listas sequenciais têm tamanho fixo, enquanto em outras (como Python), elas podem ser redimensionadas dinamicamente.
#
#   **Eficiência**: Operações de leitura (acesso a um elemento específico) são realizadas em tempo constante 𝑂(1), enquanto inserções ou remoções de elementos podem variar em eficiência, dependendo da posição do elemento.
#
#
# Também é possível ir para um tutorial on-line do Python, acesse pelo link [Lista no Python](https://docs.python.org/pt-br/3/library/stdtypes.html#list). Uma outra fonte de pesquisa pode ser na Biblioteca Virtual pelo [link](https://integrada.minhabiblioteca.com.br/reader/books/9786555584288/pageid/252)

# %%
# Exemplo de uma lista sequencial em Python
lista = [10, 20, 30, 40, 50]

# Acessando o terceiro elemento (índice 2)
elemento = lista[2]  # Resultado: 30

# Modificando o valor do primeiro elemento
lista[0] = 5  # Lista se torna: [5, 20, 30, 40, 50]

# Adicionando um novo elemento ao final da lista
lista.append(60)  # Lista se torna: [5, 20, 30, 40, 50, 60]

# Removendo o segundo elemento
del lista[1]  # Lista se torna: [5, 30, 40, 50, 60]

# %%
import numpy as np

class Listasequencial:

    def __init__(self, capacidade):
        self.capacidade = capacidade
        self.ultima_posicao = -1
        self.valores = np.empty(self.capacidade, dtype=int)

    def imprime(self):
        if self.ultima_posicao == -1:
            print('O vetor está vazio')
        else:
            for i in range(self.ultima_posicao + 1):
                print(i,' - ',self.valores[i])

    def insere(self, valor):
        if self.ultima_posicao == self.capacidade - 1:
            print('Capacidade máxima atingida...')
        else:
            self.ultima_posicao += 1
            self.valores[self.ultima_posicao] = valor

    def pesquisar(self, valor):
        for i in range(self.ultima_posicao + 1):
            if (valor==self.valores[i]):
                return i
        return -1

    def excluir(self, valor):
        posicao = self.pesquisar(valor)
        if posicao == -1:
            return -1
        else:
            for i in range(posicao, self.ultima_posicao):
                self.valores[i] = self.valores[i + 1]
        self.ultima_posicao -= 1

    def maior_valor(self):
        if self.ultima_posicao == -1:
            return None # Lista vazia, não há maior valor
        maior = self.valores[0]
        for i in range(1, self.ultima_posicao + 1):
            if self.valores[i] > maior:
                maior = self.valores[i]
        return maior

    def menor_valor(self):
        if self.ultima_posicao == -1:
            return None # Lista vazia, não há menor valor
        menor = self.valores[0]
        for i in range(1, self.ultima_posicao + 1):
            if self.valores[i] < menor:
                menor = self.valores[i]
        return menor

    def verifica_repeticao(self, valor):
        count = 0
        for i in range(self.ultima_posicao + 1):
            if self.valores[i] == valor:
                count += 1
        return count > 1

    def valores_pares(self):
        if self.ultima_posicao == -1:
            return []
        pares = []
        for i in range(self.ultima_posicao + 1):
            if self.valores[i] % 2 == 0:
                pares.append(int(self.valores[i])) # Converte para int
        return pares

    def valores_impares(self):
        if self.ultima_posicao == -1:
            return []
        impares = []
        for i in range(self.ultima_posicao + 1):
            if self.valores[i] % 2 != 0:
                impares.append(int(self.valores[i])) # Converte para int
        return impares

# %%
# Criando um objeto
p1 = Listasequencial(5)

# Inserindo os valores na minha lista
p1.insere(4)
p1.insere(13)
p1.insere(5)
p1.insere(17)
p1.insere(8)

print(p1.maior_valor())
print(p1.menor_valor())
print(p1.verifica_repeticao(5))
print(p1.valores_pares())
print(p1.valores_impares())
# Out:
# 17
# 4
# False
# [np.int64(4), np.int64(8)]
# [np.int64(13), np.int64(5), np.int64(17)]

# %%
# Criando um objeto
p1 = Listasequencial(5)

# Inserindo os valores na minha lista
p1.insere(4)
p1.insere(3)
p1.insere(5)
p1.insere(7)
p1.insere(8)
p1.insere(9)
p1.insere(12)

p1.imprime()
# Out:
# Capacidade máxima atingida...
# Capacidade máxima atingida...
# 0  -  4
# 1  -  3
# 2  -  5
# 3  -  7
# 4  -  8

# %%
# Criando um objeto
p1 = Listasequencial(5)

# Inserindo os valores na minha lista
p1.insere(4)
p1.insere(3)
p1.insere(5)
p1.insere(7)

p1.imprime()
# Out:
# 0  -  4
# 1  -  3
# 2  -  5
# 3  -  7

# %%
p1.imprime()
# Out:
# 0  -  4
# 1  -  3
# 2  -  5
# 3  -  7
# 4  -  8

# %%
p1.imprime()
# Chamando o método pesquisar para verificar se existe um valor
print('Pesquisando valores ...')
val = int(input('Informe um valor..: '))
resultado=p1.pesquisar(val)
if resultado==-1:
  print('O valor informado não existe')
else:
  print('A posição do valor ',val,' foi de',resultado)
# Out:
# 0  -  4
# 1  -  3
# 2  -  5
# 3  -  7
# 4  -  8
# Pesquisando valores ...
# Informe um valor..: 5
# A posição do valor  5  foi de 2

# %%
# Excluindo um valor da minha lista
print('Excluindo um valores ...')
p1.imprime()
p1.excluir(5)
print('--------------------')
p1.imprime()
# Out:
# Excluindo um valores ...
# 0  -  4
# 1  -  3
# 2  -  5
# 3  -  7
# --------------------
# 0  -  4
# 1  -  3
# 2  -  7

# %%
from random import randint
resposta=[]
for i in range(10):
  resposta.append(randint(10,29))

# %%
resposta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2280/420455790.py in <cell line: 0>()
# ----> 1 resposta
#
# NameError: name 'resposta' is not defined

# %%
# Criando novos métodos para o objeto Listasequencial:

# 1. Retornar o maior valor.
# 2. Retornar o menor valor.
# 3. Verificar se um valor se repete. O método deve ter um valor como parâmetro.
# 4. Retornar quais os valores são pares.
# 5. Retornar quais os valores são impares.

# %%
# Seu código aqui.

# %%
lista_exemplo = Listasequencial(10) # Cria uma lista com capacidade para 10 elementos
lista_exemplo.insere(15)
lista_exemplo.insere(22)
lista_exemplo.insere(15) # Valor repetido
lista_exemplo.insere(8)
lista_exemplo.insere(33)
lista_exemplo.insere(4)
lista_exemplo.insere(9)

print("Lista atual:")
lista_exemplo.imprime()

print("\nMaior valor:", lista_exemplo.maior_valor())
print("Menor valor:", lista_exemplo.menor_valor())
print("Verifica repetição do valor 15:", lista_exemplo.verifica_repeticao(15))
print("Verifica repetição do valor 10 (não presente):", lista_exemplo.verifica_repeticao(10))
print("Valores pares:", lista_exemplo.valores_pares())
print("Valores ímpares:", lista_exemplo.valores_impares())
# Out:
# Lista atual:
# 0  -  15
# 1  -  22
# 2  -  15
# 3  -  8
# 4  -  33
# 5  -  4
# 6  -  9
#
# Maior valor: 33
# Menor valor: 4
# Verifica repetição do valor 15: True
# Verifica repetição do valor 10 (não presente): False
# Valores pares: [np.int64(22), np.int64(8), np.int64(4)]
# Valores ímpares: [np.int64(15), np.int64(15), np.int64(33), np.int64(9)]
