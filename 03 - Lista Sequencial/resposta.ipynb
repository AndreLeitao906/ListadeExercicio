# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreLeitao906/ListadeExercicio/blob/main/03%20-%20Lista%20Sequencial/resposta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class Listasequencial:

    def __init__(self, capacidade):
        self.capacidade = capacidade
        self.ultima_posicao = -1
        self.valores = np.empty(self.capacidade, dtype=int)

    def insere(self, valor):
        if self.ultima_posicao == self.capacidade - 1:
            print('Capacidade máxima atingida')
        else:
            self.ultima_posicao += 1
            self.valores[self.ultima_posicao] = valor

    def pesquisar(self, valor):
        for i in range(self.ultima_posicao + 1):
            if valor == self.valores[i]:
                return i
        return -1

    def excluir(self, valor):
        posicao = self.pesquisar(valor)

        if posicao == -1:
            return -1
        else:
            for i in range(posicao, self.ultima_posicao):
                self.valores[i] = self.valores[i + 1]

            self.ultima_posicao -= 1

    def imprime(self):
        if self.ultima_posicao == -1:
            print('O vetor está vazio')
        else:
            for i in range(self.ultima_posicao + 1):
                print(i, ' - ', self.valores[i])

# %%
lista = Listasequencial(5)

lista.insere(101)
lista.insere(102)
lista.insere(103)
lista.insere(104)

lista.imprime()
# Out:
# 0  -  101
# 1  -  102
# 2  -  103
# 3  -  104

# %%
lista = Listasequencial(5)

lista.insere(45)
lista.insere(33)
lista.insere(27)
lista.insere(89)
lista.insere(56)

lista.imprime()

lista.insere(72)

lista.imprime()
# Out:
# 0  -  45
# 1  -  33
# 2  -  27
# 3  -  89
# 4  -  56
# Capacidade máxima atingida
# 0  -  45
# 1  -  33
# 2  -  27
# 3  -  89
# 4  -  56

# %%
lista = Listasequencial(5)

lista.insere(11)
lista.insere(22)
lista.insere(33)
lista.insere(44)
lista.insere(55)

posicao = lista.pesquisar(33)

if posicao == -1:
    print("Cliente não encontrado")
else:
    print("Cliente encontrado na posição:", posicao)
# Out:
# Cliente encontrado na posição: 2

# %%
lista = Listasequencial(5)

lista.insere(10)
lista.insere(20)
lista.insere(30)
lista.insere(40)
lista.insere(50)

lista.excluir(30)

lista.imprime()
# Out:
# 0  -  10
# 1  -  20
# 2  -  40
# 3  -  50

# %%
lista = Listasequencial(5)

lista.insere(5)
lista.insere(6)
lista.insere(7)
lista.insere(8)
lista.insere(9)

lista.excluir(7)

lista.imprime()
# Out:
# 0  -  5
# 1  -  6
# 2  -  8
# 3  -  9

# %%
lista = Listasequencial(6)

lista.insere(101)
lista.insere(103)
lista.insere(107)
lista.insere(110)
lista.insere(115)

posicao = lista.pesquisar(108)

if posicao == -1:
    print("A reserva 108 não foi cadastrada")
else:
    print("A reserva 108 está na posição:", posicao)
# Out:
# A reserva 108 não foi cadastrada

# %%
lista = Listasequencial(5)

lista.insere(2001)
lista.insere(2002)
lista.insere(2003)
lista.insere(2004)
lista.insere(2005)

lista.excluir(2002)

lista.imprime()
# Out:
# 0  -  2001
# 1  -  2003
# 2  -  2004
# 3  -  2005

# %%
lista = Listasequencial(4)

lista.insere(1234)
lista.insere(5678)
lista.insere(9101)
lista.insere(1213)

posicao = lista.pesquisar(5678)

if posicao == -1:
    print("A placa não está estacionada")
else:
    print("A placa 5678 está estacionada na posição:", posicao)

lista.insere(1415)
# Out:
# A placa 5678 está estacionada na posição: 1
# Capacidade máxima atingida

# %%
lista = Listasequencial(5)

lista.insere(70)
lista.insere(85)
lista.insere(90)
lista.insere(75)
lista.insere(60)

posicao = lista.pesquisar(75)

if posicao == -1:
    print("Nota 75 não encontrada")
else:
    print("Nota 75 encontrada na posição:", posicao)
# Out:
# Nota 75 encontrada na posição: 3

# %%
lista = Listasequencial(6)

lista.insere(1)
lista.insere(2)
lista.insere(3)
lista.insere(4)
lista.insere(5)
lista.insere(6)

lista.excluir(3)

print("Depois de excluir o 3:")
lista.imprime()

lista.excluir(5)

print("Depois de excluir o 5:")
lista.imprime()
# Out:
# Depois de excluir o 3:
# 0  -  1
# 1  -  2
# 2  -  4
# 3  -  5
# 4  -  6
# Depois de excluir o 5:
# 0  -  1
# 1  -  2
# 2  -  4
# 3  -  6
